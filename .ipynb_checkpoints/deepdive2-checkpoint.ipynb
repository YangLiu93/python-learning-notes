# %%
a = [1, #inplicit
    2,
    3]
a
# Out:
# [1, 2, 3]

# %%
b = (1,
    2 #haha
    ,3)
b
# Out:
# (1, 2, 3)

# %%
c = {'key1': 1 , #key1
    'key2' : 2}
c
# Out:
# {'key1': 1, 'key2': 2}

# %%
def my_func(a, #parameter a 
            b,
            c):
    print(a, b, c)

# %%
my_func(5 ,6 ,7)
# Out:
# (5, 6, 7)

# %%
if a>5 \
    and b > 5\
        and c > 5:
    print("yes")
# Out:
# yes

# %%
d = '''this is a multi-line
statement
by yang'''
d
# Out:
# 'this is a multi-line\nstatement\nby yang'

# %%
print(d)
# Out:
# this is a multi-line
# statement
# by yang

# %%
a = 500
if a < 10:
    print('a < 10')
else:
    if a <= 100:
        print('10 <= a <= 100')
    else:
        print('a > 100')
# Out:
# a > 100

# %%
b = 'a < 10' if a < 10 else 'a >= 10'
b
# Out:
# 'a >= 10'

# %%
def func_2(a, b):
    return a * b

# %%
func_2('a',3)
# Out:
# 'aaa'

# %%
def func_3():
    return func_4()

def func_4():
    return 'running function 4'

# %%
func_3()
# Out:
# 'running function 4'

# %%
func_3
# Out:
# <function __main__.func_3>

# %%
i = 3
while True:
    print(i)
    if i >= 5:
        break
        print(huichuxianma)
# Out:
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# ...
